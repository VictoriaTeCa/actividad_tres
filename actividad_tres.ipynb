# %% [markdown]
# <a href="https://colab.research.google.com/github/VictoriaTeCa/actividad_tres/blob/main/actividad_tres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**ACTIVIDAD TRES**

# %%
#importamos librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7ecdd1da-7b6f-4dbb-ab44-b399a67c0279" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ecdd1da-7b6f-4dbb-ab44-b399a67c0279">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Actividad2_SinNulos.csv')
data
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
#hacemos copia
data1=data.copy()

# %% [markdown]
# ### **ventas_precios_corrientes**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['ventas_precios_corrientes'])
plt.title('Outliers de ventas_precios_corrientes')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['ventas_precios_corrientes']

percentile25_uno=y.quantile(0.25) #Q1
percentile75_uno=y.quantile(0.75) #Q3
iqr_uno= percentile75_uno - percentile25_uno

Limite_Superior_iqr_uno= percentile75_uno + 1.5*iqr_uno
Limite_Inferior_iqr_uno=percentile25_uno - 1.5*iqr_uno

print('Limite superior permitido', Limite_Superior_iqr_uno)
print('Limite inferior permitido', Limite_Inferior_iqr_uno)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos Outliers
outliers_iqr_uno= data1[(y>Limite_Superior_iqr_uno)|(y<Limite_Inferior_iqr_uno)]
outliers_iqr_uno
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 25 columns]

# %%
data_clean_iqr_uno=data1[(y<=Limite_Superior_iqr_uno)&(y>=Limite_Inferior_iqr_uno)]
data_clean_iqr_uno
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_uno['ventas_precios_corrientes'])
plt.title('Outliers de Precio venta')
plt.show()

#aparece un valor atípico debido al acomodo de los índices.

# %%
data_clean_iqr_uno.to_csv('data_clean_iqr_uno.csv')

from google.colab import files
files.download('data_clean_iqr_uno.csv')

# %% [markdown]
# ## **ventas_precios_constantes**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['ventas_precios_constantes'])
plt.title('Outliers de ventas_precios_constantes')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['ventas_precios_constantes']

percentile25_dos=y.quantile(0.25) #Q1
percentile75_dos=y.quantile(0.75) #Q3
iqr_dos= percentile75_dos - percentile25_dos

Limite_Superior_iqr_dos= percentile75_dos + 1.5*iqr_dos
Limite_Inferior_iqr_dos=percentile25_dos - 1.5*iqr_dos

print('Limite superior permitido', Limite_Superior_iqr_dos)
print('Limite inferior permitido', Limite_Inferior_iqr_dos)
# Out:
# Limite superior permitido 31938.75
# Limite inferior permitido 18759.949999999997

# %%
#Encontramos Outliers
outliers_iqr_dos= data1[(y>Limite_Superior_iqr_dos)|(y<Limite_Inferior_iqr_dos)]
outliers_iqr_dos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 11          11    01/12/2017                    40766.3
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 11                    34084.5                4.076632e+07  4.032029e+07
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 11     4.460368e+05               4.076632e+07  13710305.37      11070098.74
# 42     4.726974e+06               8.114070e+07  24935747.29      22143208.63
# 60     4.819480e+06               1.545171e+08  46962602.22      46053650.13
#
#     ...       almacen    panaderia       lacteos        carnes  \
# 11  ...  9.667850e+06  1346130.813  3.684165e+06  3.674954e+06
# ...

# %%
data_clean_iqr_dos=data1[(y<=Limite_Superior_iqr_dos)&(y>=Limite_Inferior_iqr_dos)]
data_clean_iqr_dos
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_dos['ventas_precios_constantes'])
plt.title('Outliers de ventas_precios_constantes')
plt.show()

# %%
data_clean_iqr_dos.to_csv('data_clean_iqr_dos.csv')

from google.colab import files
files.download('data_clean_iqr_dos.csv')

# %% [markdown]
# ## **salon_ventas**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['salon_ventas'])
plt.title('Outliers de salon_ventas')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['salon_ventas']

percentile25_tres=y.quantile(0.25) #Q1
percentile75_tres=y.quantile(0.75) #Q3
iqr_tres= percentile75_tres - percentile25_tres

Limite_Superior_iqr_tres= percentile75_tres + 1.5*iqr_tres
Limite_Inferior_iqr_tres=percentile25_tres - 1.5*iqr_tres

print('Limite superior permitido', Limite_Superior_iqr_tres)
print('Limite inferior permitido', Limite_Inferior_iqr_tres)


#Encontramos Outliers
outliers_iqr_tres= data1[(y>Limite_Superior_iqr_tres)|(y<Limite_Inferior_iqr_tres)]
outliers_iqr_tres


#datos limpios
data_clean_iqr_tres=data1[(y<=Limite_Superior_iqr_tres)&(y>=Limite_Inferior_iqr_tres)]
data_clean_iqr_tres

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_tres['salon_ventas'])
plt.title('Outliers de salon_ventas')
plt.show()
# Out:
# Limite superior permitido 170440082.58499998
# Limite inferior permitido -32001350.254999995

# %%
data_clean_iqr_tres.to_csv('data_clean_iqr_tres.csv')

from google.colab import files
files.download('data_clean_iqr_tres.csv')

# %% [markdown]
# ## **tarjetas_debito**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['tarjetas_debito'])
plt.title('Outliers de tarjetas_debito')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['tarjetas_debito']

percentile25_4=y.quantile(0.25) #Q1
percentile75_4=y.quantile(0.75) #Q3
iqr_4= percentile75_4 - percentile25_4

Limite_Superior_iqr_4= percentile75_4 + 1.5*iqr_4
Limite_Inferior_iqr_4=percentile25_4 - 1.5*iqr_4

print('Limite superior permitido', Limite_Superior_iqr_4)
print('Limite inferior permitido', Limite_Inferior_iqr_4)


#Encontramos Outliers
outliers_iqr_4= data1[(y>Limite_Superior_iqr_4)|(y<Limite_Inferior_iqr_4)]
outliers_iqr_4


#datos limpios
data_clean_iqr_4=data1[(y<=Limite_Superior_iqr_4)&(y>=Limite_Inferior_iqr_4)]
data_clean_iqr_4

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_4['tarjetas_debito'])
plt.title('Outliers de tarjetas_debito')
plt.show()
# Out:
# Limite superior permitido 50952216.5835
# Limite inferior permitido -15349161.052499998

# %%
data_clean_iqr_4.to_csv('data_clean_iqr_4.csv')

from google.colab import files
files.download('data_clean_iqr_4.csv')

# %% [markdown]
# ## **panaderia**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['panaderia'])
plt.title('Outliers de panaderia')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['panaderia']

percentile25_5=y.quantile(0.25) #Q1
percentile75_5=y.quantile(0.75) #Q3
iqr_5= percentile75_5 - percentile25_5

Limite_Superior_iqr_5= percentile75_5 + 1.5*iqr_5
Limite_Inferior_iqr_5=percentile25_5 - 1.5*iqr_5

print('Limite superior permitido', Limite_Superior_iqr_5)
print('Limite inferior permitido', Limite_Inferior_iqr_5)


#Encontramos Outliers
outliers_iqr_5= data1[(y>Limite_Superior_iqr_5)|(y<Limite_Inferior_iqr_5)]
outliers_iqr_5


#datos limpios
data_clean_iqr_5=data1[(y<=Limite_Superior_iqr_5)&(y>=Limite_Inferior_iqr_5)]
data_clean_iqr_5

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_5['panaderia'])
plt.title('Outliers de panaderia')
plt.show()
# Out:
# Limite superior permitido 5344003.4675
# Limite inferior permitido -946571.9125000001

# %%
data_clean_iqr_5.to_csv('data_clean_iqr_5.csv')

from google.colab import files
files.download('data_clean_iqr_5.csv')

# %% [markdown]
# ## **lacteos**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['lacteos'])
plt.title('Outliers de lacteos')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['panaderia']

percentile25_6=y.quantile(0.25) #Q1
percentile75_6=y.quantile(0.75) #Q3
iqr_6= percentile75_6 - percentile25_6

Limite_Superior_iqr_6= percentile75_6 + 1.5*iqr_6
Limite_Inferior_iqr_6=percentile25_6 - 1.5*iqr_6

print('Limite superior permitido', Limite_Superior_iqr_6)
print('Limite inferior permitido', Limite_Inferior_iqr_6)


#Encontramos Outliers
outliers_iqr_6= data1[(y>Limite_Superior_iqr_6)|(y<Limite_Inferior_iqr_6)]
outliers_iqr_6


#datos limpios
data_clean_iqr_6=data1[(y<=Limite_Superior_iqr_6)&(y>=Limite_Inferior_iqr_6)]
data_clean_iqr_6

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_6['panaderia'])
plt.title('Outliers de panaderia')
plt.show()
# Out:
# Limite superior permitido 5344003.4675
# Limite inferior permitido -946571.9125000001

# %%
data_clean_iqr_6.to_csv('data_clean_iqr_6.csv')

from google.colab import files
files.download('data_clean_iqr_6.csv')

# %% [markdown]
# ## **alimentos_preparados_rotiseria**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['alimentos_preparados_rotiseria'])
plt.title('Outliers de alimentos_preparados_rotiseria')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['alimentos_preparados_rotiseria']

percentile25_7=y.quantile(0.25) #Q1
percentile75_7=y.quantile(0.75) #Q3
iqr_7= percentile75_7 - percentile25_7

Limite_Superior_iqr_7= percentile75_7 + 1.5*iqr_7
Limite_Inferior_iqr_7=percentile25_7 - 1.5*iqr_7

print('Limite superior permitido', Limite_Superior_iqr_7)
print('Limite inferior permitido', Limite_Inferior_iqr_7)


#Encontramos Outliers
outliers_iqr_7= data1[(y>Limite_Superior_iqr_7)|(y<Limite_Inferior_iqr_7)]
outliers_iqr_7


#datos limpios
data_clean_iqr_7=data1[(y<=Limite_Superior_iqr_7)&(y>=Limite_Inferior_iqr_7)]
data_clean_iqr_7

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_7['alimentos_preparados_rotiseria'])
plt.title('Outliers de alimentos_preparados_rotiseria')
plt.show()
# Out:
# Limite superior permitido 1546751.13875
# Limite inferior permitido -227313.79444999993

# %%
data_clean_iqr_7.to_csv('data_clean_iqr_7.csv')

from google.colab import files
files.download('data_clean_iqr_7.csv')

# %% [markdown]
# ## **indumentaria_calzado_textiles_hogar**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['indumentaria_calzado_textiles_hogar'])
plt.title('Outliers de indumentaria_calzado_textiles_hogar')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['indumentaria_calzado_textiles_hogar']

percentile25_8=y.quantile(0.25) #Q1
percentile75_8=y.quantile(0.75) #Q3
iqr_8= percentile75_8 - percentile25_8

Limite_Superior_iqr_8= percentile75_8 + 1.5*iqr_8
Limite_Inferior_iqr_8=percentile25_8 - 1.5*iqr_8

print('Limite superior permitido', Limite_Superior_iqr_8)
print('Limite inferior permitido', Limite_Inferior_iqr_8)


#Encontramos Outliers
outliers_iqr_8= data1[(y>Limite_Superior_iqr_8)|(y<Limite_Inferior_iqr_8)]
outliers_iqr_8


#datos limpios
data_clean_iqr_8=data1[(y<=Limite_Superior_iqr_8)&(y>=Limite_Inferior_iqr_8)]
data_clean_iqr_8

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_8['indumentaria_calzado_textiles_hogar'])
plt.title('Outliers de indumentaria_calzado_textiles_hogar')
plt.show()
# Out:
# Limite superior permitido 4001205.6905000005
# Limite inferior permitido -784042.9135000001

# %%
data_clean_iqr_8.to_csv('data_clean_iqr_8.csv')

from google.colab import files
files.download('data_clean_iqr_8.csv')

# %% [markdown]
# ## **electronicos_articulos_hogar**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['electronicos_articulos_hogar'])
plt.title('Outliers de electronicos_articulos_hogar')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['electronicos_articulos_hogar']

percentile25_9=y.quantile(0.25) #Q1
percentile75_9=y.quantile(0.75) #Q3
iqr_9= percentile75_9 - percentile25_9

Limite_Superior_iqr_9= percentile75_9 + 1.5*iqr_9
Limite_Inferior_iqr_9=percentile25_9 - 1.5*iqr_9

print('Limite superior permitido', Limite_Superior_iqr_9)
print('Limite inferior permitido', Limite_Inferior_iqr_9)


#Encontramos Outliers
outliers_iqr_9= data1[(y>Limite_Superior_iqr_9)|(y<Limite_Inferior_iqr_9)]
outliers_iqr_9


#datos limpios
data_clean_iqr_9=data1[(y<=Limite_Superior_iqr_9)&(y>=Limite_Inferior_iqr_9)]
data_clean_iqr_9

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_9['electronicos_articulos_hogar'])
plt.title('Outliers de electronicos_articulos_hogar')
plt.show()
# Out:
# Limite superior permitido 11851594.895499999
# Limite inferior permitido -3640353.060499999

# %%
data_clean_iqr_9.to_csv('data_clean_iqr_9.csv')

from google.colab import files
files.download('data_clean_iqr_9.csv')

# %% [markdown]
# ## **otros**

# %%
#diagramas de caja o bigote
#columna por columna para ver si hay datos nulos
fig= plt.figure(figsize=(10,6))
plt.boxplot(data1['otros'])
plt.title('Outliers de otros')
plt.show()

# %%
#método cuatiles, encuentro cuartiles de 0.25 y 0.75
y=data1['otros']

percentile25_10=y.quantile(0.25) #Q1
percentile75_10=y.quantile(0.75) #Q3
iqr_10= percentile75_10 - percentile25_10

Limite_Superior_iqr_10= percentile75_10 + 1.5*iqr_10
Limite_Inferior_iqr_10=percentile25_10 - 1.5*iqr_10

print('Limite superior permitido', Limite_Superior_iqr_10)
print('Limite inferior permitido', Limite_Inferior_iqr_10)


#Encontramos Outliers
outliers_iqr_10= data1[(y>Limite_Superior_iqr_10)|(y<Limite_Inferior_iqr_10)]
outliers_iqr_10


#datos limpios
data_clean_iqr_10=data1[(y<=Limite_Superior_iqr_10)&(y>=Limite_Inferior_iqr_10)]
data_clean_iqr_10

print('\n')

#diagramas de caja o bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(data_clean_iqr_10['otros'])
plt.title('Outliers de otros')
plt.show()
# Out:
# Limite superior permitido 13996998.943500001
# Limite inferior permitido -3222775.252500001

# %%
data_clean_iqr_10.to_csv('data_clean_iqr_10.csv')

from google.colab import files
files.download('data_clean_iqr_10.csv')
